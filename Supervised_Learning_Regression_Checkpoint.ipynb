# %% [markdown]
# <a href="https://colab.research.google.com/github/patech123/gomycode-data-science/blob/main/Supervised_Learning_Regression_Checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/5G_energy_consumption_dataset.csv')
df
# Out:
#                   Time      BS     Energy      load  ESMODE   TXpower
# 0      20230101 010000     B_0  64.275037  0.487936     0.0  7.101719
# 1      20230101 020000     B_0  55.904335  0.344468     0.0  7.101719
# 2      20230101 030000     B_0  57.698057  0.193766     0.0  7.101719
# 3      20230101 040000     B_0  55.156951  0.222383     0.0  7.101719
# 4      20230101 050000     B_0  56.053812  0.175436     0.0  7.101719
# ...                ...     ...        ...       ...     ...       ...
# 92624  20230102 170000  B_1018  14.648729  0.087538     0.0  7.325859
# 92625  20230102 180000  B_1018  14.648729  0.082635     0.0  7.325859
# 92626  20230102 210000  B_1018  13.452915  0.055538     0.0  7.325859
# 92627  20230102 220000  B_1018  13.602392  0.058077     0.0  7.325859
# 92628  20230102 230000  B_1018  13.303438  0.048173     0.0  7.325859
#
# [92629 rows x 6 columns]
# ...

# %%
y = df['Energy']
y
# Out:
# 0        64.275037
# 1        55.904335
# 2        57.698057
# 3        55.156951
# 4        56.053812
#            ...
# 92624    14.648729
# 92625    14.648729
# 92626    13.452915
# 92627    13.602392
# 92628    13.303438
# Name: Energy, Length: 92629, dtype: float64

# %%
X = df.drop('Energy',axis=1)
X
# Out:
#                   Time      BS      load  ESMODE   TXpower
# 0      20230101 010000     B_0  0.487936     0.0  7.101719
# 1      20230101 020000     B_0  0.344468     0.0  7.101719
# 2      20230101 030000     B_0  0.193766     0.0  7.101719
# 3      20230101 040000     B_0  0.222383     0.0  7.101719
# 4      20230101 050000     B_0  0.175436     0.0  7.101719
# ...                ...     ...       ...     ...       ...
# 92624  20230102 170000  B_1018  0.087538     0.0  7.325859
# 92625  20230102 180000  B_1018  0.082635     0.0  7.325859
# 92626  20230102 210000  B_1018  0.055538     0.0  7.325859
# 92627  20230102 220000  B_1018  0.058077     0.0  7.325859
# 92628  20230102 230000  B_1018  0.048173     0.0  7.325859
#
# [92629 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100)

# %%
X_train
# Out:
#                   Time     BS      load    ESMODE   TXpower
# 63549  20230103 080000  B_577  0.034620  0.000000  6.427504
# 36105  20230101 100000  B_329  0.064800  0.000000  6.427504
# 16256  20230105 130000  B_147  0.311160  0.000000  6.427504
# 67275  20230102 150000  B_610  0.388883  0.000000  6.875934
# 11441  20230103 220000  B_104  0.037440  0.000000  6.427504
# ...                ...    ...       ...       ...       ...
# 65615  20230103 020000  B_595  0.215870  0.000000  7.100897
# 77655  20230104 000000  B_704  0.011300  1.896944  6.875934
# 79683  20230101 110000  B_723  0.295630  0.000000  6.875934
# 56088  20230106 050000  B_510  0.070530  0.000000  7.100897
# 38408  20230105 200000  B_349  0.027280  0.000000  6.875934
#
# [74103 rows x 5 columns]

# %%
X_test
# Out:
#                   Time     BS      load  ESMODE   TXpower
# 75490  20230104 110000  B_684  0.019420     0.0  6.875934
# 42274  20230103 170000  B_385  0.043646     0.0  6.875934
# 49027  20230103 180000  B_447  0.088530     0.0  6.875934
# 5576   20230101 110000   B_51  0.112239     0.0  6.427504
# 50777  20230106 100000  B_462  0.353620     0.0  6.427504
# ...                ...    ...       ...     ...       ...
# 88383  20230103 170000  B_801  0.040560     0.0  6.427504
# 1783   20230102 070000   B_17  0.168855     0.0  7.100897
# 14013  20230105 060000  B_127  0.025372     0.0  7.100897
# 67916  20230101 130000  B_616  0.796777     0.0  6.875934
# 62399  20230101 100000  B_567  0.110350     0.0  5.680120
#
# [18526 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92629 entries, 0 to 92628
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Time     92629 non-null  object
#  1   BS       92629 non-null  object
#  2   Energy   92629 non-null  float64
#  3   load     92629 non-null  float64
#  4   ESMODE   92629 non-null  float64
#  5   TXpower  92629 non-null  float64
# dtypes: float64(4), object(2)
# memory usage: 4.2+ MB

# %%
missing_values= df.isnull().sum()
missing_values
# Out:
# Time       0
# BS         0
# Energy     0
# load       0
# ESMODE     0
# TXpower    0
# dtype: int64

# %%
df_no_duplicates = df.drop_duplicates()
print(df_no_duplicates.head())
# Out:
#               Time   BS     Energy      load  ESMODE   TXpower
# 0  20230101 010000  B_0  64.275037  0.487936     0.0  7.101719
# 1  20230101 020000  B_0  55.904335  0.344468     0.0  7.101719
# 2  20230101 030000  B_0  57.698057  0.193766     0.0  7.101719
# 3  20230101 040000  B_0  55.156951  0.222383     0.0  7.101719
# 4  20230101 050000  B_0  56.053812  0.175436     0.0  7.101719

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-d1d64243ed2d> in <cell line: 3>()
#       1 from sklearn.linear_model import LinearRegression
#       2 lr = LinearRegression()
# ----> 3 lr.fit(X_train, y_train)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     646         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     647
# --> 648         X, y = self._validate_data(
#     649             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650         )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# ...
